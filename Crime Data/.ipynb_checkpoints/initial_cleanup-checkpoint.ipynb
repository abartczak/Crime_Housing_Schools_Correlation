# %%
import pandas as pd

# %%
crime_2015_csv = "data/Police_Incidents_2015.csv"
crime_2016_csv = "data/Police_Incidents_2016.csv"
crime_2017_csv = "data/Police_Incidents_2017.csv"
crime_2018_csv = "data/Police_Incidents_2018.csv"
crime_2018_2_csv = "data/Police_Incidents_2018_2.csv"
crime_2019_csv = "data/Police_Incidents_2019.csv"

# Import the data into a Pandas DataFrame
y_2015_df = pd.read_csv(crime_2015_csv)
y_2016_df = pd.read_csv(crime_2016_csv)
y_2017_df = pd.read_csv(crime_2017_csv)
y_2018_df = pd.read_csv(crime_2018_csv)
y_2018_2_df = pd.read_csv(crime_2018_2_csv)
y_2019_df = pd.read_csv(crime_2019_csv)

# %%
y_2015_df.columns
# Out:
# Index(['PublicAddress', 'ControlNbr', 'CCN', 'Precinct', 'ReportedDate',
#        'BeginDate', 'Time', 'Offense', 'Description', 'UCRCode', 'EnteredDate',
#        'GBSID', 'Lat', 'Long', 'X', 'Y', 'Neighborhood', 'LastChanged',
#        'LastUpdateDate', 'ESRI_OID'],
#       dtype='object')

# %%
y_2015_df.head()
# Out:
#              PublicAddress  ControlNbr             CCN  Precinct  \
# 0  0015XX California ST NE     3378078  MP 2015 049484         2
# 1      0033XX Stevens AV S     3378117  MP 2015 049493         5
# 2        0030XX James AV S     3378168  MP 2015 999270         5
# 3           0032XX 34 AV S     3378172  MP 2015 049463         3
# 4        18 AV S / 31 ST E     3378179  MP 2015 049519         3
#
#                ReportedDate                 BeginDate      Time Offense  \
# 0  2015-02-11T12:30:00.000Z  2015-02-10T19:00:00.000Z  19:00:00   BURGD
# 1  2015-02-11T12:30:00.000Z  2014-09-28T08:00:00.000Z  08:00:00  AUTOTH
# 2  2015-02-11T13:24:51.000Z  2014-10-24T00:00:00.000Z  00:00:00   THEFT
# 3  2015-02-11T13:30:00.000Z  2015-02-11T12:03:00.000Z  12:03:00   BURGD
# 4  2015-02-11T13:57:00.000Z  2015-02-08T20:00:00.000Z  20:00:00  AUTOTH
#
#             Description  UCRCode               EnteredDate    GBSID  \
# 0  Burglary Of Dwelling        6  2015-02-11T12:29:49.000Z  12782.0
# ...

# %%
#Remove unnecessary columns
year_2015_df = y_2015_df[["PublicAddress", "Precinct", "BeginDate", "Offense", "Description", "Lat", "Long", "Neighborhood"]]
year_2015_df
# Out:
#                  PublicAddress  Precinct                 BeginDate Offense  \
# 0      0015XX California ST NE         2  2015-02-10T19:00:00.000Z   BURGD
# 1          0033XX Stevens AV S         5  2014-09-28T08:00:00.000Z  AUTOTH
# 2            0030XX James AV S         5  2014-10-24T00:00:00.000Z   THEFT
# 3               0032XX 34 AV S         3  2015-02-11T12:03:00.000Z   BURGD
# 4            18 AV S / 31 ST E         3  2015-02-08T20:00:00.000Z  AUTOTH
# ...                        ...       ...                       ...     ...
# 19993     0026XX Humboldt AV S         5  2015-05-07T00:12:00.000Z  ROBPER
# 19994        18 AV S / 26 ST E         3  2015-05-07T00:25:00.000Z  ROBPAG
# 19995          0005XX 14 AV SE         2  2015-05-06T23:15:00.000Z   THEFT
# 19996       0031XX Bryant AV S         5  2015-05-07T00:20:00.000Z  ROBPAG
# 19997       0043XX Colfax AV S         5  2015-05-07T02:42:00.000Z  AUTOTH
#
#                 Description        Lat       Long     Neighborhood
# ...

# %%
#Remove unnecessary columns
year_2016_df = y_2016_df[["PublicAddress", "Precinct", "BeginDate", "Offense", "Description", "Lat", "Long", "Neighborhood"]]
year_2016_df
# Out:
#                     PublicAddress  Precinct                 BeginDate Offense  \
# 0                00001X Lake ST W         5  2016-02-14T13:30:00.000Z   THEFT
# 1                 0006XX 19 AV NE         2  2016-02-15T20:00:00.000Z    CSCR
# 2                   0015XX 4 ST S         1  2016-02-16T21:00:00.000Z  ROBPER
# 3              0037XX Bryant AV S         5  2016-02-16T11:15:00.000Z   THEFT
# 4           0039XX Minnehaha AV S         3  2016-02-15T21:00:00.000Z   BURGD
# ...                           ...       ...                       ...     ...
# 20150              0003XX 5 AV SE         2  2016-10-31T08:00:00.000Z  BIKETF
# 20151        0055XX Pleasant AV S         5  2016-10-28T00:00:00.000Z   THEFT
# 20152           0061XX Colfax LN          5  2016-11-04T09:00:00.000Z   BURGD
# 20153  Essex ST SE / St Marys AV          2  2016-11-04T16:10:00.000Z   ASLT2
# 20154          0027XX Dupont AV S         5  2016-11-04T09:00:00.000Z   BURGD
#
# ...

# %%
#Remove unnecessary columns
year_2017_df = y_2017_df[["PublicAddress", "Precinct", "BeginDate", "Offense", "Description", "Lat", "Long", "Neighborhood"]]
year_2017_df
# Out:
#                    PublicAddress  Precinct                 BeginDate Offense  \
# 0                0010XX 27 AV SE       2.0  2017-04-08T15:43:00.000Z   THEFT
# 1         0006XX Nicollet Mall         1.0  2017-04-12T11:37:00.000Z   THEFT
# 2      Broadway AV W / Penn AV N       4.0  2017-05-12T01:30:00.000Z    CSCR
# 3          0019XX Marshall ST NE       2.0  2017-05-13T23:55:00.000Z    TFMV
# 4                 0000XX 6 AV SE       2.0  2017-05-14T03:10:00.000Z  ROBPAG
# ...                          ...       ...                       ...     ...
# 22080     0007XX Washington AV N       1.0  2017-02-07T21:40:00.000Z   TFPER
# 22081         0013XX Girard AV N       4.0  2017-02-07T13:50:00.000Z   THEFT
# 22082             0006XX 8 ST SE       2.0  2017-02-07T23:35:00.000Z   BURGD
# 22083        0013XX Fremont AV N       4.0  2017-02-07T21:58:00.000Z    TFMV
# 22084      0004XX Marquette AV S       1.0  2017-02-08T00:54:00.000Z   DASTR
#
# ...

# %%
#Remove unnecessary columns
year_2018_df = y_2018_df[["PublicAddress", "Precinct", "BeginDate", "Offense", "Description", "Lat", "Long", "Neighborhood"]]
year_2018_df
# Out:
#                PublicAddress  Precinct                 BeginDate Offense  \
# 0        0036XX Harriet AV S         5  2018-05-23T22:00:00.000Z   BURGD
# 1             0026XX 15 AV S         3  2018-05-24T02:00:00.000Z   BURGD
# 2       0025XX Central AV NE         2  2018-05-24T09:49:00.000Z   THEFT
# 3     0024XX Washington AV N         4  2018-04-07T09:00:00.000Z  THFTSW
# 4             0005XX 15 AV S         1  2018-05-24T00:30:00.000Z    TFMV
# ...                      ...       ...                       ...     ...
# 7345      0002XX Colfax AV N         4  2018-05-23T23:45:00.000Z   BURGB
# 7346          0004XX 10 ST S         1  2018-05-23T19:45:00.000Z  AUTOTH
# 7347      0050XX Colfax AV S         5  2018-05-23T23:30:00.000Z   BURGD
# 7348          0036XX 14 AV S         3  2018-05-24T05:30:00.000Z   BURGD
# 7349   0021XX Blaisdell AV S         5  2018-05-23T11:30:00.000Z  ROBPAG
#
#                Description        Lat       Long      Neighborhood
# ...

# %%
y_2018_2_df.columns
# Out:
# Index(['X', 'Y', 'publicaddress', 'caseNumber', 'precinct', 'reportedDate',
#        'reportedTime', 'beginDate', 'reportedDateTime', 'beginTime', 'offense',
#        'description', 'UCRCode', 'enteredDate', 'centergbsid', 'centerLong',
#        'centerLat', 'centerX', 'centerY', 'neighborhood', 'lastchanged',
#        'LastUpdateDateETL', 'OBJECTID'],
#       dtype='object')

# %%
#Remove unnecessary columns and rename columns to be consistent with other dataframes
year_2018_2_df = y_2018_2_df[["publicaddress", "precinct", "beginDate", "offense", "description", "centerLat", "centerLong", "neighborhood"]]
year_2018_2_df=year_2018_2_df.rename(columns={"publicaddress":"PublicAddress", "precinct":"Precinct", "beginDate":"BeginDate", "offense":"Offense", "description":"Description", "centerLat":"Lat", "centerLong":"Long", "neighborhood":"Neighborhood"}) 
year_2018_2_df
# Out:
#               PublicAddress Precinct                 BeginDate   Offense  \
# 0      0036XX HENNEPIN AVE    5       2018-12-08T00:00:00.000Z  TFMV
# 1          0008XX LAKE ST E   3       2018-12-08T00:00:00.000Z  SHOPLF
# 2      0036XX HENNEPIN AVE    5       2018-12-08T00:00:00.000Z  TFMV
# 3          0043XX 1ST AVE S   5       2018-12-07T00:00:00.000Z  THEFT
# 4      0054XX LYNDALE AVE S   5       2018-12-08T00:00:00.000Z  THFTSW
# ...                     ...      ...                       ...       ...
# 11599  0028XX FREMONT AVE S   5       2018-06-08T00:00:00.000Z  BIKETF
# 11600   0002XX CHURCH ST SE   2       2018-06-26T00:00:00.000Z  BIKETF
# 11601   0022XX CLINTON AVE    5       2018-06-18T00:00:00.000Z  THEFT
# 11602     0041XX 13TH AVE S   3       2018-06-30T00:00:00.000Z  TFMV
# 11603      0009XX 7TH ST SE   2       2018-06-30T00:00:00.000Z  TFMV
#
#                           Description        Lat       Long  \
# ...

# %%
#Remove unnecessary columns and rename columns to be consistent with other dataframes
year_2019_df = y_2019_df[["publicaddress", "precinct", "beginDate", "offense", "description", "centerLat", "centerLong", "neighborhood"]]
year_2019_df=year_2019_df.rename(columns={"publicaddress":"PublicAddress", "precinct":"Precinct", "beginDate":"BeginDate", "offense":"Offense", "description":"Description", "centerLat":"Lat", "centerLong":"Long", "neighborhood":"Neighborhood"})
year_2019_df
# Out:
#                   PublicAddress Precinct                 BeginDate   Offense  \
# 0             0034XX 33RD AVE S   3       2019-03-23T00:00:00.000Z  TFMV
# 1               0001XX 5TH ST N   1       2019-03-22T00:00:00.000Z  THFTSW
# 2             0028XX 26TH AVE S   3       2019-03-23T00:00:00.000Z  SHOPLF
# 3        0011XX NICOLLET MALL     1       2019-03-23T00:00:00.000Z  BURGB
# 4                           NaN   3       2019-03-23T00:00:00.000Z  TFPER
# ...                         ...      ...                       ...       ...
# 29038         0030XX 31ST AVE S   3       2020-02-20T00:00:00.000Z  AUTOTH
# 29039         0029XX 12TH AVE S   3       2020-02-20T00:00:00.000Z  AUTOTH
# 29040                       NaN   3       2020-02-01T00:00:00.000Z  TMVP
# 29041  0013XX UNIVERSITY AVE SE   2       2020-02-20T00:00:00.000Z  THEFT
# 29042          00001X LAKE ST W   5       2020-02-20T00:00:00.000Z  TMVP
#
# ...

# %%
#Rename columns in all dataframes to be consistent
year_2015_df=year_2015_df.rename(columns={"PublicAddress":"Address", "BeginDate":"Offense Date", "Lat":"Latitude", "Long":"Longitude"})
year_2016_df=year_2016_df.rename(columns={"PublicAddress":"Address", "BeginDate":"Offense Date", "Lat":"Latitude", "Long":"Longitude"})
year_2017_df=year_2017_df.rename(columns={"PublicAddress":"Address", "BeginDate":"Offense Date", "Lat":"Latitude", "Long":"Longitude"})
year_2018_df=year_2018_df.rename(columns={"PublicAddress":"Address", "BeginDate":"Offense Date", "Lat":"Latitude", "Long":"Longitude"})
year_2018_2_df=year_2018_2_df.rename(columns={"PublicAddress":"Address", "BeginDate":"Offense Date", "Lat":"Latitude", "Long":"Longitude"})
year_2019_df=year_2019_df.rename(columns={"PublicAddress":"Address", "BeginDate":"Offense Date", "Lat":"Latitude", "Long":"Longitude"})

# %%
year_2015_df
# Out:
#                        Address  Precinct              Offense Date Offense  \
# 0      0015XX California ST NE         2  2015-02-10T19:00:00.000Z   BURGD
# 1          0033XX Stevens AV S         5  2014-09-28T08:00:00.000Z  AUTOTH
# 2            0030XX James AV S         5  2014-10-24T00:00:00.000Z   THEFT
# 3               0032XX 34 AV S         3  2015-02-11T12:03:00.000Z   BURGD
# 4            18 AV S / 31 ST E         3  2015-02-08T20:00:00.000Z  AUTOTH
# ...                        ...       ...                       ...     ...
# 19993     0026XX Humboldt AV S         5  2015-05-07T00:12:00.000Z  ROBPER
# 19994        18 AV S / 26 ST E         3  2015-05-07T00:25:00.000Z  ROBPAG
# 19995          0005XX 14 AV SE         2  2015-05-06T23:15:00.000Z   THEFT
# 19996       0031XX Bryant AV S         5  2015-05-07T00:20:00.000Z  ROBPAG
# 19997       0043XX Colfax AV S         5  2015-05-07T02:42:00.000Z  AUTOTH
#
#                 Description   Latitude  Longitude     Neighborhood
# ...

# %%
#Combine separate dataframes into one dataframe
frames = [year_2015_df, year_2016_df, year_2017_df, year_2018_df, year_2018_2_df, year_2019_df]
crime_df = pd.concat(frames)
crime_df
# Out:
#                         Address Precinct              Offense Date   Offense  \
# 0       0015XX California ST NE        2  2015-02-10T19:00:00.000Z     BURGD
# 1           0033XX Stevens AV S        5  2014-09-28T08:00:00.000Z    AUTOTH
# 2             0030XX James AV S        5  2014-10-24T00:00:00.000Z     THEFT
# 3                0032XX 34 AV S        3  2015-02-11T12:03:00.000Z     BURGD
# 4             18 AV S / 31 ST E        3  2015-02-08T20:00:00.000Z    AUTOTH
# ...                         ...      ...                       ...       ...
# 29038         0030XX 31ST AVE S   3       2020-02-20T00:00:00.000Z  AUTOTH
# 29039         0029XX 12TH AVE S   3       2020-02-20T00:00:00.000Z  AUTOTH
# 29040                       NaN   3       2020-02-01T00:00:00.000Z  TMVP
# 29041  0013XX UNIVERSITY AVE SE   2       2020-02-20T00:00:00.000Z  THEFT
# 29042          00001X LAKE ST W   5       2020-02-20T00:00:00.000Z  TMVP
#
# ...

# %%
#Export to csv file
crime_df.to_csv("data/All_Crime_Data.csv", index=False, header=True)

# %%
#Drop empty rows
crime_df = crime_df.dropna()
crime_df
# Out:
#                         Address Precinct              Offense Date   Offense  \
# 0       0015XX California ST NE        2  2015-02-10T19:00:00.000Z     BURGD
# 1           0033XX Stevens AV S        5  2014-09-28T08:00:00.000Z    AUTOTH
# 2             0030XX James AV S        5  2014-10-24T00:00:00.000Z     THEFT
# 3                0032XX 34 AV S        3  2015-02-11T12:03:00.000Z     BURGD
# 4             18 AV S / 31 ST E        3  2015-02-08T20:00:00.000Z    AUTOTH
# ...                         ...      ...                       ...       ...
# 29037       0018XX STEVENS AVE    5       2020-02-20T00:00:00.000Z  AUTOTH
# 29038         0030XX 31ST AVE S   3       2020-02-20T00:00:00.000Z  AUTOTH
# 29039         0029XX 12TH AVE S   3       2020-02-20T00:00:00.000Z  AUTOTH
# 29041  0013XX UNIVERSITY AVE SE   2       2020-02-20T00:00:00.000Z  THEFT
# 29042          00001X LAKE ST W   5       2020-02-20T00:00:00.000Z  TMVP
#
# ...

# %%
#Begin process of correcting crime descriptions so that all similar crimes have the same description
crime_df["Description"].value_counts()
# Out:
# Other Theft                       19491
# Theft From Motr Vehc              10335
# Burglary Of Dwelling               9501
# OTHER THEFT                        7843
# THEFT FROM MOTR VEHC               6650
#                                   ...
# Looting                               1
# DISARM A POLICE OFFICER               1
# ACCESS/ALTER SYSTEM/NETWORK           1
# MURDER - 2ND DEGREE                   1
# LOOTING                               1
# Name: Description, Length: 80, dtype: int64

# %%
#Continue process
new_crime_df = crime_df.replace({"Domestic Assault/Strangulation":"Domestic Assault",
                             "Theft From Building":"Theft from Building",
                             "Robbery Of Business":"Robbery of Business",
                             "Robbery Of Person":"Robbery of Person",
                             "Murder (general)":"Murder",
                             "Murder (GENERAL)":"Murder",
                             "MURDER (GENERAL)":"Murder",
                             "Pocket-picking":"Pocket-Picking",
                             "MURDER (GENERAL)              ":"Murder",
                             "Theft By Swindle":"Theft by Swindle",
                             "Theft From Person":"Theft from Person",
                             "Theft By Computer":"Theft by Computer",
                             "Other Vehicle Theft":"Other Automobile Theft",
                             "Burglary Of Business":"Burglary of Business",
                             "Burglary Of Dwelling": "Burglary of Dwelling",
                             "Other Theft                   ":"Other Theft",
                             "BURGLARY OF DWELLING          ": "Burglary of Dwelling",
                             "Automobile Theft              ":"Automobile Theft",
                             "ASSLT W/DNGRS WEAPON          ":"Assault - Dangerous Weapon",
                             "Asslt W/dngrs Weapon":"Assault - Dangerous Weapon",
                             "THEFT FROM PERSON SNATCH/GRAB ":"Theft from Person",
                             "2nd Deg Domes Aslt":"Domestic Assault",
                             "Aslt-police/emerg P":"Assault of Police Officer",
                             "Robbery Per Agg":"Aggravated Robbery",
                             "Aslt-sgnfcnt Bdly Hm":"Assault",
                             "Crim Sex Cond-rape":"Criminal Sexual Conduct",
                             "Theft-motr Veh Parts":"Theft - Automobile Parts",
                             "Gas Station Driv-off":"Gas Station Drive-off",
                             "3rd Deg Domes Aslt":"Domestic Assault",
                             "Aslt-great Bodily Hm":"Assault",
                             "1st Deg Domes Asslt":"Domestic Assault",
                             "Theft from Automobile          ":"Theft from Automobile",
                             "ROBBERY PER AGG               ":"Aggravated Robbery",
                             "3RD DEG DOMES ASLT            ":"Domestic Assault",
                             "ROBBERY OF PERSON             ":"Robbery of Person",
                             "2ND DEG DOMES ASLT            ":"Domestic Assault",
                             "CSC - RAPE                    ":"Criminal Sexual Conduct",
                             "BURGLARY OF BUSINESS          ":"Burglary of Business",
                             "ROBBERY OF BUSINESS           ":"Robbery of Business",
                             "ASLT-SGNFCNT BDLY HM          ":"Assault",
                             "ON-LINE THEFT                 ":"On-line Theft",
                             "THEFT FROM BUILDING           ":"Theft from Building",
                             "DOMESTIC ASSAULT/STRANGULATION":"Domestic Assault",
                             "THEFT-MOTR VEH PARTS          ":"Theft - Automobile Parts",
                             "BIKE THEFT                    ":"Bike Theft",
                             "COMPUTER HACKING              ":"Computer Hacking",
                             "ARSON-1ST DEGREE              ":"Arson",
                             "THEFT/COINOP DEVICE           ":"Theft/coinop Device",
                             "OBS - PETTY THEFT             ":"Petty Theft",
                             "MURDER - 1ST DEGREE           ":"Murder",
                             "ASLT-GREAT BODILY HM          ":"Assault",
                             "OTHER VEHICLE THEFT           ":"Other Automobile Theft",
                             "Murder (general)":"Murder",
                             "1ST DEG DOMES ASLT            ":"Domestic Assault",
                             "POCKET-PICKING                ":"Pocket-Picking",
                             "SCRAPPING-RECYCLING THEFT     ":"Scrapping-Recycling Theft",
                             "ASLT4-LESS THAN SUBST HARM    ":"Assault of Police Officer",
                             "CSC - SODOMY                  ":"Criminal Sexual Conduct",
                             "ARSON                         ":"Arson",
                             "MURDER (GENERAL)              ":"Murder",
                             "CSC - PENETRATE WITH OBJECT   ":"Criminal Sexual Conduct",
                             "HACKING - THEFT OF SERVICE    ":"Computer Hacking",
                             "ASLT4-SUBST HARM OR WEAPON    ":"Assault of Police Officer",
                             "OBS - COMPUTER HACKING        ":"Computer Hacking",
                             "OBS-CSCR - USE EXT 1, 2 OR 3  ":"Criminal Sexual Conduct",
                             "GAS STATION DRIV-OFF          ":"Gas Station Drive-off",
                             "ACCESS/ALTER SYSTEM/NETWORK   ":"Computer Hacking",
                             "LOOTING                       ":"Looting",
                             "MURDER - 2ND DEGREE           ":"Murder",
                             "DISARM A POLICE OFFICER       ":"Disarm a Police Officer",
                             "SHOPLIFTING                   ":"Shoplifting", 
                             "THEFT BY SWINDLE              ": "Theft by Swindle", 
                             "OTHER THEFT": "Other Theft", 
                             "Other Theft                   ":"Other Theft", 
                             "Theft From Motr Vehc":"Theft from Automobile", 
                             "THEFT FROM MOTR VEHC": "Theft from Automobile", 
                             "AUTOMOBILE THEFT": "Automobile Theft",
                             "OBS - ASLT-POLICE/EMERG P     ":"Assault of Police Officer",
                             "Motor Vehicle Theft": "Automobile Theft"}, regex=True)

# %%
#Continue process
new_crime_df["Description"].unique()
# Out:
# array(['Burglary of Dwelling', 'Automobile Theft', 'Other Theft',
#        'Theft from Automobile', 'Domestic Assault',
#        'Burglary of Business', 'Shoplifting', 'Bike Theft',
#        'Robbery of Person', 'Arson', 'Assault - Dangerous Weapon',
#        'Assault of Police Officer', 'Aggravated Robbery',
#        'Theft by Swindle', 'Assault', 'Criminal Sexual Conduct',
#        'Theft from Person', 'Theft from Building', 'Robbery of Business',
#        'Theft - Automobile Parts', 'Other Automobile Theft',
#        'Scrapping-Recycling Theft', 'Gas Station Drive-off',
#        'Murder (general)', 'Looting', 'Theft/coinop Device',
#        'On-line Theft', 'Theft by Computer', 'Disarm a Police Officer',
#        'Pocket-Picking', 'Computer Hacking', 'Petty Theft', 'Murder',
#        'MURDER (GENERAL)              '], dtype=object)

# %%
#Continue process
new_crime_df["Description"].unique()
# Out:
# array(['Burglary of Dwelling', 'Automobile Theft', 'Other Theft',
#        'Theft from Automobile', 'Domestic Assault',
#        'Burglary of Business', 'Shoplifting', 'Bike Theft',
#        'Robbery of Person', 'Arson', 'Assault - Dangerous Weapon',
#        'Assault of Police Officer', 'Aggravated Robbery',
#        'Theft by Swindle', 'Assault', 'Criminal Sexual Conduct',
#        'Theft from Person', 'Theft from Building', 'Robbery of Business',
#        'Theft - Automobile Parts', 'Other Automobile Theft',
#        'Scrapping-Recycling Theft', 'Gas Station Drive-off',
#        'Murder (general)', 'Looting', 'Theft/coinop Device',
#        'On-line Theft', 'Theft by Computer', 'Disarm a Police Officer',
#        'Pocket-Picking', 'Computer Hacking', 'Petty Theft', 'Murder',
#        'MURDER (GENERAL)              '], dtype=object)

# %%
#Continue process
new_crime = new_crime_df.replace({'Murder (general)':'Murder', 'MURDER (GENERAL)              ':'Murder'})

# %%
#Continue process
new_crime['Description'].value_counts()
# Out:
# Other Theft                   27334
# Theft from Automobile         16985
# Burglary of Dwelling          13939
# Automobile Theft              10881
# Shoplifting                    5021
# Bike Theft                     4058
# Aggravated Robbery             3649
# Domestic Assault               3512
# Burglary of Business           3499
# Assault - Dangerous Weapon     3494
# Robbery of Person              2724
# Theft by Swindle               1847
# Criminal Sexual Conduct        1628
# Theft from Person              1462
# Theft - Automobile Parts       1046
# Assault                         965
# Theft from Building             716
# Robbery of Business             572
# Assault of Police Officer       448
# Arson                           434
# Other Automobile Theft          145
# Murder                          142
# On-line Theft                    67
# Theft/coinop Device              53
# Gas Station Drive-off            25
# Pocket-Picking                   22
# ...

# %%
#Create new date of offense column and split value to eliminate extraneous information
new_crime["Date of Offense"] = new_crime["Offense Date"].str.split(pat = "T").str[0]

# %%
#Drop unnecessary columns
new_crime = new_crime.drop(["Offense Date", "Address"], axis=1)

# %%
#Review final dataframe
new_crime
# Out:
#       Precinct   Offense               Description   Latitude  Longitude  \
# 0            2     BURGD      Burglary of Dwelling  45.003332 -93.268892
# 1            5    AUTOTH          Automobile Theft  44.942254 -93.275357
# 2            5     THEFT               Other Theft  44.947480 -93.303384
# 3            3     BURGD      Burglary of Dwelling  44.944096 -93.222936
# 4            3    AUTOTH          Automobile Theft  44.946560 -93.248680
# ...        ...       ...                       ...        ...        ...
# 29037   5       AUTOTH            Automobile Theft  44.964585 -93.275292
# 29038   3       AUTOTH            Automobile Theft  44.947613 -93.227081
# 29039   3       AUTOTH            Automobile Theft  44.949226 -93.257578
# 29041   2       THEFT                  Other Theft  44.979795 -93.237257
# 29042   5       TMVP      Theft - Automobile Parts  44.948347 -93.278808
#
#                            Neighborhood Date of Offense
# ...

# %%
#Export dataframe to csv to continue analysis in another notebook.  
#This is done to save time as rerunning the cell changing the names of the crimes takes significant time and resources
new_crime.to_csv("data/Clean_Crime_Data.csv", index=False, header=True)
